# %% [markdown]
# # Assignment #2: Data Exploration
#
# In this assignment, you will demonstrate your knowledge of the Python and Pandas skills we've learned so far. These include:
#
# - Getting an overview of your data
# - Extracting columns
# - Removing duplicates from your data
# - Creating a subset of your data by matching a string
# - Getting a random sample of your data
# - Sorting your data
# - Getting fundamental statistical information of a series, such as the mean and median
#
# You will not need to formulate or answer a research question for this assignment. You simply need to demonstrate your ability to perform specific operations on the data set you have selected. In the next assignment, your midterm, you will create a narrative exploration of the data using many of the same methods, but in such a way as to use narrative along with data analysis to answer a research question.
#
# You may use the data set you imported in assignment #1, or you may choose another data set. That means that you can reuse code you wrote in Assignment #1 to import the data.
#
# In the below notebook, I will ask for you to perform a task. Each task will be followed by one or more blank code cells. Use as many cells as you need to complete the task. If you know some other way to complete the task with Python and/or Pandas that is not the way we learned in class, that is also acceptable. Feel free to use Google searches to refresh your memory as to how to perform each task. You will also likely wish to consult the class notebooks, which can be found in [our class repository on GitHub](https://github.com/sha256rma/foundations-of-data-science).
#
# If your data set does not have a needed form of data for a task, write code that would perform the task if a column with that data existed, and provide an explanation as a comment or markdown cell.
#
# You may receive partial credit for some incomplete or incorrect answers. Please feel free to add comments about your thought process, which will make it more likely that you will receive partial credit.
#
# The last cell is a bonus. You will not be penalized for not attempting or completing it.
#
# -----

# %% [markdown]
# Import Pandas and read your data in as a data frame. Assign the data frame to a variable, such as `df`.

# %%
import pandas as pd

# %%
df = pd.read_excel("/Users/lucaslarsen/Documents/CCNY Python Portfolio/foundations-of-data-science/assignments/greenbookUS.xlsx")

# %% [markdown]
# Make the data frame visible by placing the data frame variable in a cell by itself.

# %%
df
# Out:
#        Fiscal Year                        Region                Country  \
# 0           1946.0  Middle East and North Africa                  Egypt
# 1           1946.0  Middle East and North Africa                  Egypt
# 2           1946.0  Middle East and North Africa                   Iran
# 3           1946.0  Middle East and North Africa                Lebanon
# 4           1946.0  Middle East and North Africa           Saudi Arabia
# ...            ...                           ...                    ...
# 72632       2019.0                         World  World (not specified)
# 72633       2019.0                         World  World (not specified)
# 72634       2019.0                         World  World (not specified)
# 72635       2019.0                         World  World (not specified)
# 72636       2019.0                         World  World (not specified)
#
#       Assistance Category                                Publication Row  \
# 0                Economic                              Inactive Programs
# 1                Economic                              Inactive Programs
# 2                Economic                              Inactive Programs
# 3                Economic                              Inactive Programs
# 4                Economic                              Inactive Programs
# ...                   ...                                            ...
# 72632            Military                     Foreign Military Financing
# 72633            Military  International Military Education and Training
# 72634            Military                       Peace Keeping Operations
# 72635            Military                      Other Military Assistance
# 72636            Military                      Other Military Assistance
#
#                        Funding Agency  \
# 0      Unknown - Historical Greenbook
# 1      Unknown - Historical Greenbook
# 2      Unknown - Historical Greenbook
# 3      Unknown - Historical Greenbook
# 4          Department of the Treasury
# ...                               ...
# 72632             Department of State
# 72633             Department of State
# 72634             Department of State
# 72635           Department of Defense
# 72636           Department of Defense
#
#                                 Funding Account Name  \
# 0                     INACTIVE - US Surplus Property
# 1       INACTIVE - UN Relif and Rehab Agency (UNRRA)
# 2                     INACTIVE - US Surplus Property
# 3                     INACTIVE - US Surplus Property
# 4                       INACTIVE - Lend Lease Silver
# ...                                              ...
# 72632             Foreign Military Financing Program
# 72633  International Military Education and Training
# 72634                       Peace Keeping Operations
# 72635           Operation and Maintenance, Air Force
# 72636        Operation and Maintenance, Defense-Wide
#
#        Obligations (Historical Dollars)  Obligations (Constant Dollars)
# 0                          9.300000e+06                    1.000840e+08
# 1                          3.000000e+05                    3.228517e+06
# 2                          3.300000e+06                    3.551368e+07
# 3                          1.600000e+06                    1.721876e+07
# 4                          2.400000e+06                    2.582813e+07
# ...                                 ...                             ...
# 72632                      1.976689e+06                    1.976689e+06
# 72633                      3.635807e+06                    3.635807e+06
# 72634                      1.147500e+08                    1.147500e+08
# 72635                      3.000000e+06                    3.000000e+06
# 72636                      3.979332e+07                    3.979332e+07
#
# [72637 rows x 9 columns]

# %% [markdown]
# What columns are in your data frame? Use a function or method that shows all the columns.

# %%
data_columns=df.columns

# %%
data_columns
# Out:
# Index(['Fiscal Year', 'Region', 'Country', 'Assistance Category',
#        'Publication Row', 'Funding Agency', 'Funding Account Name',
#        'Obligations (Historical Dollars)', 'Obligations (Constant Dollars)'],
#       dtype='object')

# %% [markdown]
# Write Python code to output the number of rows in your data frame.

# %%
len(df.index)
# Out:
# 72637

# %% [markdown]
# Write code to output a column from your data frame as a series. (Extract a column.)

# %%
first_series=pd.Series(df.Country)

# %%
print(first_series)
# Out:
# 0                        Egypt
# 1                        Egypt
# 2                         Iran
# 3                      Lebanon
# 4                 Saudi Arabia
#                  ...
# 72632    World (not specified)
# 72633    World (not specified)
# 72634    World (not specified)
# 72635    World (not specified)
# 72636    World (not specified)
# Name: Country, Length: 72637, dtype: object

# %% [markdown]
# ### Read the example below to **count** duplicates based on specific columns (e.g., 'Name' and 'Age')
#
# Check duplicates based on 'Name' and 'Age' columns (modify the subset for your own columns):
#
# `duplicates_subset = df.duplicated(subset=['Name', 'Age'])`
#
# Count the number of duplicates in the subset:
#
# `num_duplicates_subset = duplicates_subset.sum()`
#
# Display no. of duplicate rows based on your column(s):
#
# `print(f"\nNumber of duplicate rows based on 'Name' and 'Age': {num_duplicates_subset}")`

# %% [markdown]
# After reading the above, modify the code snippets to check for duplicate columns in your own data frame

# %%
duplicates_subset = df.duplicated(subset=['Country', 'Assistance Category', 'Fiscal Year'])

# %%
num_duplicates_subset = duplicates_subset.sum()

# %%
print(f"\nNumber of duplicate rows based on 'Country' and 'Assistance Category' and 'Fiscal Year': {num_duplicates_subset}")
# Out:
# Number of duplicate rows based on 'Country' and 'Assistance Category' and 'Fiscal Year': 56721

# %% [markdown]
# If any duplicates exist within a column, remove them with the `.drop_duplicates()` function

# %%
df.drop_duplicates()
# Out:
#        Fiscal Year                        Region                Country  \
# 0           1946.0  Middle East and North Africa                  Egypt
# 1           1946.0  Middle East and North Africa                  Egypt
# 2           1946.0  Middle East and North Africa                   Iran
# 3           1946.0  Middle East and North Africa                Lebanon
# 4           1946.0  Middle East and North Africa           Saudi Arabia
# ...            ...                           ...                    ...
# 72632       2019.0                         World  World (not specified)
# 72633       2019.0                         World  World (not specified)
# 72634       2019.0                         World  World (not specified)
# 72635       2019.0                         World  World (not specified)
# 72636       2019.0                         World  World (not specified)
#
#       Assistance Category                                Publication Row  \
# 0                Economic                              Inactive Programs
# 1                Economic                              Inactive Programs
# 2                Economic                              Inactive Programs
# 3                Economic                              Inactive Programs
# 4                Economic                              Inactive Programs
# ...                   ...                                            ...
# 72632            Military                     Foreign Military Financing
# 72633            Military  International Military Education and Training
# 72634            Military                       Peace Keeping Operations
# 72635            Military                      Other Military Assistance
# 72636            Military                      Other Military Assistance
#
#                        Funding Agency  \
# 0      Unknown - Historical Greenbook
# 1      Unknown - Historical Greenbook
# 2      Unknown - Historical Greenbook
# 3      Unknown - Historical Greenbook
# 4          Department of the Treasury
# ...                               ...
# 72632             Department of State
# 72633             Department of State
# 72634             Department of State
# 72635           Department of Defense
# 72636           Department of Defense
#
#                                 Funding Account Name  \
# 0                     INACTIVE - US Surplus Property
# 1       INACTIVE - UN Relif and Rehab Agency (UNRRA)
# 2                     INACTIVE - US Surplus Property
# 3                     INACTIVE - US Surplus Property
# 4                       INACTIVE - Lend Lease Silver
# ...                                              ...
# 72632             Foreign Military Financing Program
# 72633  International Military Education and Training
# 72634                       Peace Keeping Operations
# 72635           Operation and Maintenance, Air Force
# 72636        Operation and Maintenance, Defense-Wide
#
#        Obligations (Historical Dollars)  Obligations (Constant Dollars)
# 0                          9.300000e+06                    1.000840e+08
# 1                          3.000000e+05                    3.228517e+06
# 2                          3.300000e+06                    3.551368e+07
# 3                          1.600000e+06                    1.721876e+07
# 4                          2.400000e+06                    2.582813e+07
# ...                                 ...                             ...
# 72632                      1.976689e+06                    1.976689e+06
# 72633                      3.635807e+06                    3.635807e+06
# 72634                      1.147500e+08                    1.147500e+08
# 72635                      3.000000e+06                    3.000000e+06
# 72636                      3.979332e+07                    3.979332e+07
#
# [72637 rows x 9 columns]

# %% [markdown]
# Write Python code to output the number of rows in your data frame.

# %%
len(df.index)
# Out:
# 72637

# %% [markdown]
# Compare the new value with the first time you outputted the number of rows above. Is it more, less, or the same?

# %% [markdown]
# #### The value is the same as the first time I outputted the number of rows.

# %% [markdown]
# Create a subset of the data that matches a specific string in a column. That is, extract all rows of the original data frame that contain a specific string in one of the columns. Save the resulting data frame to a variable. (Add more cells if needed)

# %%
specific_string = 'Yemen'

# %%
subset_df=df[df['Country']== specific_string]

# %% [markdown]
# Output the length of the resulting data frame (the subset of your data for which the conditional was true).

# %%
subset_df
# Out:
#        Fiscal Year                        Region Country Assistance Category  \
# 2635        1959.0  Middle East and North Africa   Yemen            Economic
# 2636        1959.0  Middle East and North Africa   Yemen            Economic
# 3045        1960.0  Middle East and North Africa   Yemen            Economic
# 3046        1960.0  Middle East and North Africa   Yemen            Economic
# 3468        1961.0  Middle East and North Africa   Yemen            Economic
# ...            ...                           ...     ...                 ...
# 70299       2019.0  Middle East and North Africa   Yemen            Economic
# 70300       2019.0  Middle East and North Africa   Yemen            Economic
# 70301       2019.0  Middle East and North Africa   Yemen            Economic
# 70302       2019.0  Middle East and North Africa   Yemen            Military
# 70303       2019.0  Middle East and North Africa   Yemen            Military
#
#                                          Publication Row  \
# 2635                              Other USAID Assistance
# 2636                      Public Law 480 Title II Grants
# 3045                              Other USAID Assistance
# 3046                      Public Law 480 Title II Grants
# 3468                              Other USAID Assistance
# ...                                                  ...
# 70299  Nonproliferation, Anti-Terrorism, Demining & R...
# 70300                             Other State Assistance
# 70301            Department of Health and Human Services
# 70302                         Foreign Military Financing
# 70303                          Other Military Assistance
#
#                                   Funding Agency  \
# 2635   U.S. Agency for International Development
# 2636                   Department of Agriculture
# 3045   U.S. Agency for International Development
# 3046                   Department of Agriculture
# 3468   U.S. Agency for International Development
# ...                                          ...
# 70299                        Department of State
# 70300                        Department of State
# 70301    Department of Health and Human Services
# 70302                        Department of State
# 70303                      Department of Defense
#
#                                     Funding Account Name  \
# 2635                             INACTIVE - USAID Grants
# 2636                      Public Law 480 Title II Grants
# 3045                             INACTIVE - USAID Grants
# 3046                      Public Law 480 Title II Grants
# 3468                             INACTIVE - USAID Grants
# ...                                                  ...
# 70299  Nonproliferation, Anti-Terrorism, Demining and...
# 70300  National Endowment for Democracy, Department o...
# 70301  CDC-Wide Activities and Program Support, Cente...
# 70302                 Foreign Military Financing Program
# 70303            Operation and Maintenance, Defense-Wide
#
#        Obligations (Historical Dollars)  Obligations (Constant Dollars)
# 2635                          300000.00                    2.059707e+06
# 2636                         4800000.00                    3.295531e+07
# 3045                         3000000.00                    2.031186e+07
# 3046                         2600000.00                    1.760361e+07
# 3468                         4000000.00                    2.672846e+07
# ...                                 ...                             ...
# 70299                        6479420.50                    6.479420e+06
# 70300                         891714.00                    8.917140e+05
# 70301                         -95478.37                   -9.547837e+04
# 70302                         919009.36                    9.190094e+05
# 70303                          17002.97                    1.700297e+04
#
# [436 rows x 9 columns]

# %% [markdown]
# Output the first ten rows of your data set, the last ten rows of your data set, and a random ten rows of your data set (a sample of your data).

# %%
df.iloc[0:10]
# Out:
#    Fiscal Year                        Region       Country  \
# 0       1946.0  Middle East and North Africa         Egypt
# 1       1946.0  Middle East and North Africa         Egypt
# 2       1946.0  Middle East and North Africa          Iran
# 3       1946.0  Middle East and North Africa       Lebanon
# 4       1946.0  Middle East and North Africa  Saudi Arabia
# 5       1946.0  Middle East and North Africa  Saudi Arabia
# 6       1946.0            Sub-Saharan Africa      Ethiopia
# 7       1946.0            Sub-Saharan Africa       Liberia
# 8       1946.0   Latin America and Caribbean     Argentina
# 9       1946.0   Latin America and Caribbean       Bolivia
#
#   Assistance Category    Publication Row                  Funding Agency  \
# 0            Economic  Inactive Programs  Unknown - Historical Greenbook
# 1            Economic  Inactive Programs  Unknown - Historical Greenbook
# 2            Economic  Inactive Programs  Unknown - Historical Greenbook
# 3            Economic  Inactive Programs  Unknown - Historical Greenbook
# 4            Economic  Inactive Programs      Department of the Treasury
# 5            Economic  Inactive Programs  Unknown - Historical Greenbook
# 6            Economic  Inactive Programs  Unknown - Historical Greenbook
# 7            Economic  Inactive Programs      Department of the Treasury
# 8            Economic  Inactive Programs  Unknown - Historical Greenbook
# 9            Economic  Inactive Programs  Unknown - Historical Greenbook
#
#                              Funding Account Name  \
# 0                  INACTIVE - US Surplus Property
# 1    INACTIVE - UN Relif and Rehab Agency (UNRRA)
# 2                  INACTIVE - US Surplus Property
# 3                  INACTIVE - US Surplus Property
# 4                    INACTIVE - Lend Lease Silver
# 5                  INACTIVE - US Surplus Property
# 6                  INACTIVE - US Surplus Property
# 7                    INACTIVE - Lend Lease Silver
# 8                 INACTIVE - Technical Assistance
# 9  INACTIVE - Institute of American Affairs (IAA)
#
#    Obligations (Historical Dollars)  Obligations (Constant Dollars)
# 0                         9300000.0                    1.000840e+08
# 1                          300000.0                    3.228517e+06
# 2                         3300000.0                    3.551368e+07
# 3                         1600000.0                    1.721876e+07
# 4                         2400000.0                    2.582813e+07
# 5                         1900000.0                    2.044727e+07
# 6                          400000.0                    4.304689e+06
# 7                         6800000.0                    7.317971e+07
# 8                            1000.0                    1.076172e+04
# 9                          400000.0                    4.304689e+06

# %%
df.iloc[72626:72636]
# Out:
#        Fiscal Year Region                Country Assistance Category  \
# 72626       2019.0  World  World (not specified)            Economic
# 72627       2019.0  World  World (not specified)            Economic
# 72628       2019.0  World  World (not specified)            Economic
# 72629       2019.0  World  World (not specified)            Economic
# 72630       2019.0  World  World (not specified)            Economic
# 72631       2019.0  World  World (not specified)            Military
# 72632       2019.0  World  World (not specified)            Military
# 72633       2019.0  World  World (not specified)            Military
# 72634       2019.0  World  World (not specified)            Military
# 72635       2019.0  World  World (not specified)            Military
#
#                                      Publication Row  \
# 72626                     Department of the Treasury
# 72627                     Department of the Treasury
# 72628                Environmental Protection Agency
# 72629                                    Peace Corps
# 72630                   Trade and Development Agency
# 72631                   Cooperative Threat Reduction
# 72632                     Foreign Military Financing
# 72633  International Military Education and Training
# 72634                       Peace Keeping Operations
# 72635                      Other Military Assistance
#
#                         Funding Agency  \
# 72626       Department of the Treasury
# 72627       Department of the Treasury
# 72628  Environmental Protection Agency
# 72629                      Peace Corps
# 72630     Trade and Development Agency
# 72631            Department of Defense
# 72632              Department of State
# 72633              Department of State
# 72634              Department of State
# 72635            Department of Defense
#
#                                     Funding Account Name  \
# 72626  Contribution to the International Fund for Agr...
# 72627         International Affairs Technical Assistance
# 72628  Environmental Programs and Management, Environ...
# 72629                                        Peace Corps
# 72630                       Trade and Development Agency
# 72631      Cooperative Threat Reduction Account, Defense
# 72632                 Foreign Military Financing Program
# 72633      International Military Education and Training
# 72634                           Peace Keeping Operations
# 72635               Operation and Maintenance, Air Force
#
#        Obligations (Historical Dollars)  Obligations (Constant Dollars)
# 72626                      3.000000e+07                    3.000000e+07
# 72627                      9.947131e+06                    9.947131e+06
# 72628                      4.009400e+07                    4.009400e+07
# 72629                      2.654432e+08                    2.654432e+08
# 72630                      2.413109e+06                    2.413109e+06
# 72631                      2.021600e+07                    2.021600e+07
# 72632                      1.976689e+06                    1.976689e+06
# 72633                      3.635807e+06                    3.635807e+06
# 72634                      1.147500e+08                    1.147500e+08
# 72635                      3.000000e+06                    3.000000e+06

# %%
random_sample=df.sample(n=10)

# %%
random_sample
# Out:
#        Fiscal Year                       Region                  Country  \
# 6908        1967.0           Sub-Saharan Africa               Seychelles
# 66972       2017.0                 Central Asia                  Armenia
# 24911       1998.0                 Central Asia  Eurasia (not specified)
# 14544       1982.0                        World    World (not specified)
# 66407       2017.0  Latin America and Caribbean                     Peru
# 72370       2019.0               Eastern Europe     Bosnia & Herzegovina
# 46189       2010.0           Sub-Saharan Africa               Mozambique
# 34039       2005.0           Sub-Saharan Africa             Burkina Faso
# 44222       2009.0  Latin America and Caribbean                Nicaragua
# 21326       1994.0           Sub-Saharan Africa      Congo (Brazzaville)
#
#       Assistance Category                   Publication Row  \
# 6908             Economic    Public Law 480 Title II Grants
# 66972            Economic             Refugee and Migration
# 24911            Economic            Other USAID Assistance
# 14544            Economic        Department of the Treasury
# 66407            Economic                    Democracy Fund
# 72370            Economic            Other USAID Assistance
# 46189            Economic            Other State Assistance
# 34039            Economic  Millennium Challenge Corporation
# 44222            Economic            Development Assistance
# 21326            Economic            Other USAID Assistance
#
#                                   Funding Agency  \
# 6908                   Department of Agriculture
# 66972                        Department of State
# 24911  U.S. Agency for International Development
# 14544                 Department of the Treasury
# 66407                        Department of State
# 72370  U.S. Agency for International Development
# 46189                        Department of State
# 34039           Millennium Challenge Corporation
# 44222  U.S. Agency for International Development
# 21326  U.S. Agency for International Development
#
#                                     Funding Account Name  \
# 6908                      Public Law 480 Title II Grants
# 66972  Migration and Refugee Assistance, Department o...
# 24911                            INACTIVE - USAID Grants
# 14544       Contribution to the African Development Fund
# 66407                Democracy Fund, Department of State
# 72370        Development Credit Authority, United States
# 46189                         Global HIV/AIDs Initiative
# 34039                   Millennium Challenge Corporation
# 44222                             Development Assistance
# 21326                            INACTIVE - USAID Grants
#
#        Obligations (Historical Dollars)  Obligations (Constant Dollars)
# 6908                       1.000000e+03                    6.030027e+03
# 66972                      4.050000e+05                    4.224682e+05
# 24911                      3.075660e+08                    4.583736e+08
# 14544                      5.833300e+07                    1.345392e+08
# 66407                      3.121710e+05                    3.256354e+05
# 72370                      7.689686e+05                    7.689686e+05
# 46189                      4.081902e+06                    4.770845e+06
# 34039                      2.300495e+04                    2.968261e+04
# 44222                      1.751020e+07                    2.064148e+07
# 21326                      8.830000e+05                    1.410943e+06

# %% [markdown]
# ## Bonus
#
# You may want to refer to the [Pandas Cheat Sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf).

# %% [markdown]
# Sort your data frame by a particular column and output the result.

# %%
df.sort_values ('Country')
# Out:
#        Fiscal Year              Region      Country Assistance Category  \
# 12546       1978.0                Asia  Afghanistan            Economic
# 33055       2004.0                Asia  Afghanistan            Economic
# 33056       2004.0                Asia  Afghanistan            Economic
# 33057       2004.0                Asia  Afghanistan            Economic
# 33058       2004.0                Asia  Afghanistan            Economic
# ...            ...                 ...          ...                 ...
# 38947       2007.0  Sub-Saharan Africa     Zimbabwe            Economic
# 38948       2007.0  Sub-Saharan Africa     Zimbabwe            Economic
# 38949       2007.0  Sub-Saharan Africa     Zimbabwe            Economic
# 25376       1999.0  Sub-Saharan Africa     Zimbabwe            Economic
# 30819       2003.0  Sub-Saharan Africa     Zimbabwe            Economic
#
#                                          Publication Row  \
# 12546                     Public Law 480 Title II Grants
# 33055                             Transition Initiatives
# 33056                             Other USAID Assistance
# 33057                             Other USAID Assistance
# 33058                             Other USAID Assistance
# ...                                                  ...
# 38947                             Other USAID Assistance
# 38948                             Other USAID Assistance
# 38949                             Other USAID Assistance
# 25376  Economic Support Fund/Security Support Assistance
# 30819                     African Development Foundation
#
#                                   Funding Agency  \
# 12546                  Department of Agriculture
# 33055  U.S. Agency for International Development
# 33056  U.S. Agency for International Development
# 33057  U.S. Agency for International Development
# 33058  U.S. Agency for International Development
# ...                                          ...
# 38947  U.S. Agency for International Development
# 38948  U.S. Agency for International Development
# 38949  U.S. Agency for International Development
# 25376  U.S. Agency for International Development
# 30819             African Development Foundation
#
#                                     Funding Account Name  \
# 12546                     Public Law 480 Title II Grants
# 33055  Transition Initiatives, International Assistan...
# 33056             Capital Investment Fund, United States
# 33057                        Operating Expenses of USAID
# 33058  Assistance for the Independent States of the F...
# ...                                                  ...
# 38947                        Operating Expenses of USAID
# 38948         Sub-Saharan Africa, Development Assistance
# 38949  Child Survival and Health Programs Fund, Unite...
# 25376                              Economic Support Fund
# 30819                     African Development Foundation
#
#        Obligations (Historical Dollars)  Obligations (Constant Dollars)
# 12546                         642000.00                    2.043570e+06
# 33055                        7827300.08                    1.040740e+07
# 33056                         422500.00                    5.617681e+05
# 33057                        9013876.18                    1.198511e+07
# 33058                        5000000.00                    6.648144e+06
# ...                                 ...                             ...
# 38947                        2168566.13                    2.639361e+06
# 38948                        1957163.99                    2.382063e+06
# 38949                       15477900.20                    1.883815e+07
# 25376                         500000.00                    7.357059e+05
# 30819                         501970.00                    6.834328e+05
#
# [72637 rows x 9 columns]

# %% [markdown]
# Pick a column in your data set with numeric data (integers or floats). Output the mean (average) and median of that column.

# %%
dollar_average = df['Obligations (Constant Dollars)'].mean()

# %%
dollar_average
# Out:
# 38775130.59329926

# %%
dollar_median = df['Obligations (Constant Dollars)'].median()

# %%
dollar_median
# Out:
# 1409003.5597484282
