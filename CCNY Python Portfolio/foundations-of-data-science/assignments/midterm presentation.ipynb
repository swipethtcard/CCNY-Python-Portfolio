# %%
import pandas as pd
USAIDF=pd.read_excel("/Users/lucaslarsen/Documents/CCNY Python Portfolio/foundations-of-data-science/assignments/greenbookUS.xlsx")
ChileDF = USAIDF[(USAIDF['Country'] == 'Chile')]

# %%
ChileDF
# Out:
#        Fiscal Year                       Region Country Assistance Category  \
# 12          1946.0  Latin America and Caribbean   Chile            Economic
# 91          1947.0  Latin America and Caribbean   Chile            Economic
# 174         1948.0  Latin America and Caribbean   Chile            Economic
# 246         1949.0  Latin America and Caribbean   Chile            Economic
# 325         1950.0  Latin America and Caribbean   Chile            Economic
# ...            ...                          ...     ...                 ...
# 71247       2019.0  Latin America and Caribbean   Chile            Economic
# 71248       2019.0  Latin America and Caribbean   Chile            Economic
# 71249       2019.0  Latin America and Caribbean   Chile            Economic
# 71250       2019.0  Latin America and Caribbean   Chile            Military
# 71251       2019.0  Latin America and Caribbean   Chile            Military
#
#                                      Publication Row  \
# ...

# %%
import matplotlib.pyplot as plt

plt.close("all")

# %%
ChileDF.set_index('Fiscal Year', inplace=True)

# %%
ChileDF.reset_index(inplace=True)

# %%
plt.scatter(ChileDF['Fiscal Year'], ChileDF['Obligations (Constant Dollars)'], color='blue')
plt.title('US Aid to Chile')
plt.xlabel('Fiscal Year')
plt.ylabel('Obligations (Constant Dollars)')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
ChileMDF=ChileDF[(ChileDF['Assistance Category'] == 'Military')]

# %%
ChileMDF
# Out:
#      Fiscal Year                       Region Country Assistance Category  \
# 7         1952.0  Latin America and Caribbean   Chile            Military
# 9         1953.0  Latin America and Caribbean   Chile            Military
# 10        1953.0  Latin America and Caribbean   Chile            Military
# 12        1954.0  Latin America and Caribbean   Chile            Military
# 13        1954.0  Latin America and Caribbean   Chile            Military
# ..           ...                          ...     ...                 ...
# 461       2017.0  Latin America and Caribbean   Chile            Military
# 469       2018.0  Latin America and Caribbean   Chile            Military
# 470       2018.0  Latin America and Caribbean   Chile            Military
# 477       2019.0  Latin America and Caribbean   Chile            Military
# 478       2019.0  Latin America and Caribbean   Chile            Military
#
#                                    Publication Row         Funding Agency  \
# ...

# %%
ChileMDF.set_index('Fiscal Year', inplace=True)
ChileMDF.reset_index(inplace=True)
plt.scatter(ChileMDF['Fiscal Year'], ChileMDF['Obligations (Constant Dollars)'], color='blue')
plt.title('US Aid to Chile')
plt.xlabel('Fiscal Year')
plt.ylabel('Obligations (Constant Dollars)')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
ChileEDF=ChileDF[(ChileDF['Assistance Category'] == 'Economic')]

# %%
ChileEDF
# Out:
#      Fiscal Year                       Region Country Assistance Category  \
# 0         1946.0  Latin America and Caribbean   Chile            Economic
# 1         1947.0  Latin America and Caribbean   Chile            Economic
# 2         1948.0  Latin America and Caribbean   Chile            Economic
# 3         1949.0  Latin America and Caribbean   Chile            Economic
# 4         1950.0  Latin America and Caribbean   Chile            Economic
# ..           ...                          ...     ...                 ...
# 472       2019.0  Latin America and Caribbean   Chile            Economic
# 473       2019.0  Latin America and Caribbean   Chile            Economic
# 474       2019.0  Latin America and Caribbean   Chile            Economic
# 475       2019.0  Latin America and Caribbean   Chile            Economic
# 476       2019.0  Latin America and Caribbean   Chile            Economic
#
#                                        Publication Row  \
# ...

# %%
ChileEDF.set_index('Fiscal Year', inplace=True)
ChileEDF.reset_index(inplace=True)
plt.scatter(ChileEDF['Fiscal Year'], ChileEDF['Obligations (Constant Dollars)'], color='blue')
plt.title('US Aid to Chile')
plt.xlabel('Fiscal Year')
plt.ylabel('Obligations (Constant Dollars)')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
ChileEDF['Obligations (Constant Dollars)'].quantile([0.25,0.75])
# Out:
# 0.25    1.026128e+05
# 0.75    1.018619e+07
# Name: Obligations (Constant Dollars), dtype: float64

# %%
ChileEDF['Obligations (Constant Dollars)'].describe()
# Out:
# count    3.320000e+02
# mean     2.203622e+07
# std      8.035404e+07
# min     -1.671025e+06
# 25%      1.026128e+05
# 50%      1.286201e+06
# 75%      1.018619e+07
# max      9.261412e+08
# Name: Obligations (Constant Dollars), dtype: float64

# %%
mean_C = ChileEDF['Obligations (Constant Dollars)'].mean()
std_C = ChileEDF['Obligations (Constant Dollars)'].std()

lower_bound = mean_C - 3 * std_C
upper_bound = mean_C + 3 * std_C

FChileEDF = ChileEDF[(ChileEDF['Obligations (Constant Dollars)'] >= lower_bound) & (ChileEDF['Obligations (Constant Dollars)'] <= upper_bound)]

# %%
FChileEDF.set_index('Fiscal Year', inplace=True)
FChileEDF.reset_index(inplace=True)
plt.scatter(FChileEDF['Fiscal Year'], FChileEDF['Obligations (Constant Dollars)'], color='blue')
plt.title('US Economic Aid to Chile (no outliers)')
plt.xlabel('Fiscal Year')
plt.ylabel('Obligations (Constant Dollars)')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
USAIDF=pd.read_excel("/Users/lucaslarsen/Documents/CCNY Python Portfolio/foundations-of-data-science/assignments/greenbookUS.xlsx")

# %%
CCount=USAIDF['Country'].value_counts()

# %%
CCount
# Out:
# Country
# World (not specified)    1847
# Philippines               946
# Peru                      917
# Guatemala                 902
# Thailand                  852
#                          ...
# Sweden                     25
# New Zealand                22
# Kiribati                   22
# Brunei                     15
# Switzerland                14
# Name: count, Length: 204, dtype: int64

# %%
MCount=USAIDF['Assistance Category'].value_counts()
MCount
# Out:
# Assistance Category
# Economic    58221
# Military    14416
# Name: count, dtype: int64

# %%
MDF=USAIDF[USAIDF['Assistance Category']== 'Military']

# %%
MDFCount=MDF['Country'].value_counts()

# %%
MDFCount
# Out:
# Country
# Philippines                        251
# Turkey                             218
# Thailand                           208
# World (not specified)              206
# Greece                             206
#                                   ...
# Western Europe (not specified)       2
# Central America (not specified)      2
# West Africa (not specified)          1
# Korea, North                         1
# Eurasia (not specified)              1
# Name: count, Length: 203, dtype: int64

# %%
EDF=USAIDF[USAIDF['Assistance Category']== 'Economic']
EDFCount=EDF['Country'].value_counts()
EDFCount
# Out:
# Country
# World (not specified)    1641
# Guatemala                 752
# Peru                      737
# Kenya                     733
# Philippines               695
#                          ...
# St. Lucia                  12
# Brunei                     10
# Dominica                   10
# St. Kitts and Nevis         8
# Switzerland                 8
# Name: count, Length: 204, dtype: int64

# %%
EDF['Obligations (Constant Dollars)'].min()
# Out:
# -5402852429.842569

# %%
EDF['Obligations (Constant Dollars)'].max()
# Out:
# 36386971527.17872

# %%
highestE=EDF[EDF['Obligations (Constant Dollars)']== 36386971527.17872]
highestE
# Out:
#      Fiscal Year          Region         Country Assistance Category  \
# 165       1947.0  Western Europe  United Kingdom            Economic
#
#        Publication Row              Funding Agency     Funding Account Name  \
# 165  Inactive Programs  Department of the Treasury  INACTIVE - British Loan
#
#      Obligations (Historical Dollars)  Obligations (Constant Dollars)
# 165                      3.750000e+09                    3.638697e+10

# %%
lowestE=EDF[EDF['Obligations (Constant Dollars)']== -5402852429.842569]
lowestE
# Out:
#       Fiscal Year Region               Country Assistance Category  \
# 1108       1954.0   Asia  Asia (not specified)            Economic
#
#              Publication Row                             Funding Agency  \
# 1108  Other USAID Assistance  U.S. Agency for International Development
#
#                                    Funding Account Name  \
# 1108  INACTIVE - ESF adjustment for USAID Loans and ...
#
#       Obligations (Historical Dollars)  Obligations (Constant Dollars)
# 1108                      -701900000.0                   -5.402852e+09

# %%
MDF['Obligations (Constant Dollars)'].min()
# Out:
# -476651655.629138

# %%
MDF['Obligations (Constant Dollars)'].max()
# Out:
# 14860350190.008175

# %%
highestM=MDF[MDF['Obligations (Constant Dollars)']== 14860350190.008175]
highestM
# Out:
#       Fiscal Year Region  Country Assistance Category  \
# 9987       1973.0   Asia  Vietnam            Military
#
#                 Publication Row                  Funding Agency  \
# 9987  Other Military Assistance  Unknown - Historical Greenbook
#
#         Funding Account Name  Obligations (Historical Dollars)  \
# 9987  INACTIVE - MASF Grants                      3.226834e+09
#
#       Obligations (Constant Dollars)
# 9987                    1.486035e+10

# %%
lowestM=MDF[MDF['Obligations (Constant Dollars)']== -476651655.629138]
lowestM
# Out:
#       Fiscal Year Region                Country Assistance Category  \
# 3409       1960.0  World  World (not specified)            Military
#
#                 Publication Row         Funding Agency  \
# 3409  Other Military Assistance  Department of Defense
#
#          Funding Account Name  Obligations (Historical Dollars)  \
# 3409  Excess Defense Articles                       -70400000.0
#
#       Obligations (Constant Dollars)
# 3409                   -4.766517e+08

# %%
NKMAid = MDF[MDF['Country'] == 'Korea, North']
NKMAid
# Out:
#        Fiscal Year Region       Country Assistance Category  \
# 31348       2003.0   Asia  Korea, North            Military
#
#                           Publication Row         Funding Agency  \
# 31348  Drug Interdiction and Counter-Drug  Department of Defense
#
#                                     Funding Account Name  \
# 31348  Drug Interdiction and Counter-Drug Activities,...
#
#        Obligations (Historical Dollars)  Obligations (Constant Dollars)
# 31348                            6000.0                     8169.007264

# %%
PhDF = USAIDF[(USAIDF['Country'] == 'Philippines')]
import matplotlib.pyplot as plt

plt.close("all")
PhDF.set_index('Fiscal Year', inplace=True)
PhDF.reset_index(inplace=True)
plt.scatter(PhDF['Fiscal Year'], PhDF['Obligations (Constant Dollars)'], color='blue')
plt.title('US Aid to Philippines')
plt.xlabel('Fiscal Year')
plt.ylabel('Obligations (Constant Dollars)')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
plt.scatter(PhDF['Fiscal Year'], PhDF['Obligations (Historical Dollars)'], color='blue')
plt.title('US Aid to Philippines')
plt.xlabel('Fiscal Year')
plt.ylabel('Obligations (Historical Dollars)')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
IsDF = USAIDF[(USAIDF['Country'] == 'Israel')]
plt.scatter(IsDF['Fiscal Year'], IsDF['Obligations (Historical Dollars)'], color='blue')
plt.title('US Aid to Israel')
plt.xlabel('Fiscal Year')
plt.ylabel('Obligations (Historical Dollars)')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
IsDF = USAIDF[(USAIDF['Country'] == 'Israel')]
plt.scatter(IsDF['Fiscal Year'], IsDF['Obligations (Constant Dollars)'], color='blue')
plt.title('US Aid to Israel')
plt.xlabel('Fiscal Year')
plt.ylabel('Obligations (Constant Dollars)')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
SoDF = USAIDF[(USAIDF['Country'] == 'Somalia')]
plt.scatter(SoDF['Fiscal Year'], SoDF['Obligations (Historical Dollars)'], color='blue')
plt.title('US Aid to Somalia')
plt.xlabel('Fiscal Year')
plt.ylabel('Obligations (Historical Dollars)')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
EDF=USAIDF[USAIDF['Assistance Category']== 'Economic']
EDFCount=EDF['Region'].value_counts()
EDFCount
# Out:
# Region
# Sub-Saharan Africa              19074
# Latin America and Caribbean     13207
# Asia                             9441
# Middle East and North Africa     4918
# Central Asia                     4167
# Eastern Europe                   3095
# World                            1728
# Western Europe                   1682
# Oceania                           909
# Name: count, dtype: int64

# %%
MDF=USAIDF[USAIDF['Assistance Category']== 'Military']
MDFCount=MDF['Region'].value_counts()
MDFCount
# Out:
# Region
# Latin America and Caribbean     3866
# Sub-Saharan Africa              2992
# Asia                            2260
# Middle East and North Africa    1537
# Western Europe                  1353
# Eastern Europe                  1135
# Central Asia                     784
# Oceania                          266
# World                            223
# Name: count, dtype: int64

# %%
LADF=MDF[MDF['Region']== 'Latin America and Caribbean']
LADFCount=LADF['Country'].value_counts()
LADFCount
# Out:
# Country
# Colombia                                     202
# Dominican Republic                           199
# Honduras                                     190
# Peru                                         180
# El Salvador                                  162
# Ecuador                                      160
# Panama                                       152
# Guatemala                                    150
# Chile                                        147
# Uruguay                                      145
# Brazil                                       143
# Paraguay                                     136
# Bolivia                                      136
# Argentina                                    130
# Mexico                                       127
# Nicaragua                                    127
# Jamaica                                      111
# Haiti                                        107
# Costa Rica                                   103
# ...

# %%
CoLADF=LADF[LADF['Country']=='Colombia']
plt.scatter(CoLADF['Fiscal Year'], CoLADF['Obligations (Historical Dollars)'], color='blue')
plt.title('US Military Aid to Colombia')
plt.xlabel('Fiscal Year')
plt.ylabel('Obligations (Historical Dollars)')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
MEDF=USAIDF[USAIDF['Region']== 'Middle East and North Africa']
MEDFCount=MEDF['Country'].value_counts()
MEDFCount
# Out:
# Country
# Jordan                                        746
# Morocco                                       674
# Egypt                                         666
# Tunisia                                       526
# Lebanon                                       508
# Iraq                                          456
# Yemen                                         436
# Israel                                        402
# Middle East & North Africa (not specified)    363
# West Bank/Gaza                                245
# Algeria                                       233
# Libya                                         220
# Oman                                          215
# Iran                                          207
# Syria                                         182
# Saudi Arabia                                  122
# Bahrain                                       122
# United Arab Emirates                           65
# Kuwait                                         35
# ...

# %%
MEEDF=EDF[EDF['Region']== 'Middle East and North Africa']
MEEDFCount=MEEDF['Country'].value_counts()
MEEDFCount
# Out:
# Country
# Jordan                                        545
# Egypt                                         539
# Morocco                                       500
# Lebanon                                       378
# Yemen                                         366
# Iraq                                          360
# Middle East & North Africa (not specified)    345
# Tunisia                                       343
# Israel                                        292
# West Bank/Gaza                                239
# Algeria                                       182
# Syria                                         171
# Libya                                         169
# Iran                                          135
# Oman                                          127
# Saudi Arabia                                   62
# United Arab Emirates                           55
# Bahrain                                        51
# Kuwait                                         31
# ...

# %%
MEMDF=MDF[MDF['Region']== 'Middle East and North Africa']
MEMDFCount=MEMDF['Country'].value_counts()
MEMDFCount
# Out:
# Country
# Jordan                                        201
# Tunisia                                       183
# Morocco                                       174
# Lebanon                                       130
# Egypt                                         127
# Israel                                        110
# Iraq                                           96
# Oman                                           88
# Iran                                           72
# Bahrain                                        71
# Yemen                                          70
# Saudi Arabia                                   60
# Libya                                          51
# Algeria                                        51
# Middle East & North Africa (not specified)     18
# Syria                                          11
# United Arab Emirates                           10
# West Bank/Gaza                                  6
# Kuwait                                          4
# ...

# %%
IsDF['Assistance Category'].value_counts()
# Out:
# Assistance Category
# Economic    292
# Military    110
# Name: count, dtype: int64

# %%
IsDF['Obligations (Historical Dollars)'].sum()
# Out:
# 135542780888.93991

# %%
IsDF['Obligations (Historical Dollars)'].describe()
# Out:
# count    4.020000e+02
# mean     3.371711e+08
# std      8.245362e+08
# min     -1.950050e+09
# 25%      5.000000e+05
# 50%      1.500000e+07
# 75%      5.000000e+08
# max      3.300000e+09
# Name: Obligations (Historical Dollars), dtype: float64

# %%
ISDF=IsDF[IsDF['Obligations (Historical Dollars)']>=0]

# %%
plt.scatter(ISDF['Fiscal Year'], ISDF['Obligations (Historical Dollars)'], color='blue')
plt.title('US Aid to Israel')
plt.xlabel('Fiscal Year')
plt.ylabel('Obligations (Historical Dollars)')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
IsDF['Funding Account Name'].value_counts()
# Out:
# Funding Account Name
# Foreign Military Financing Program                                                     46
# Economic Support Fund                                                                  42
# INACTIVE - USAID Grants                                                                39
# INACTIVE - ESF adjustment for USAID Loans and Grants                                   28
# Excess Defense Articles                                                                26
# Foreign Military Financing, Direct Loan Program Account                                26
# Public Law 480 Title I Food for Progress Credits, Program Account                      25
# Public Law 480 Title II Grants                                                         24
# Migration and Refugee Assistance, Department of  State                                 23
# INACTIVE - USAID Loans                                                                 19
# ...

# %%
NEDF=USAIDF[USAIDF['Funding Account Name'] =='National Endowment for Democracy, Department of State']
NEDF['Country'].value_counts()
# Out:
# Country
# Nicaragua    30
# Guatemala    30
# Nigeria      30
# Ukraine      30
# Vietnam      30
#              ..
# Guyana        1
# Singapore     1
# Oman          1
# Lesotho       1
# Maldives      1
# Name: count, Length: 147, dtype: int64

# %%
NEDF['Region'].value_counts()
# Out:
# Region
# Sub-Saharan Africa              761
# Asia                            442
# Latin America and Caribbean     411
# Middle East and North Africa    335
# Central Asia                    300
# Eastern Europe                  223
# Western Europe                   30
# World                            30
# Name: count, dtype: int64

# %%
FMFPDF=USAIDF[USAIDF['Funding Account Name'].isin(['Foreign Military Financing Program','Foreign Military Financing, Direct Loan Program Account','Excess Defense Articles'])]
FMFPDF['Country'].value_counts()
# Out:
# Country
# Israel                             98
# Jordan                             84
# Morocco                            82
# Philippines                        80
# Turkey                             78
#                                    ..
# Singapore                           2
# Germany                             2
# Central America (not specified)     2
# Equatorial Guinea                   1
# New Zealand                         1
# Name: count, Length: 166, dtype: int64

# %%
FMFPDFgrouped = FMFPDF.groupby('Country')['Obligations (Historical Dollars)'].sum().reset_index()
FMFPDFgrouped
# Out:
#                    Country  Obligations (Historical Dollars)
# 0              Afghanistan                      1.118922e+09
# 1                  Albania                      9.025864e+07
# 2                   Angola                      2.950000e+06
# 3      Antigua and Barbuda                      1.278800e+07
# 4                Argentina                      2.405349e+08
# ..                     ...                               ...
# 161                Vietnam                      1.193578e+09
# 162  World (not specified)                      1.407172e+09
# 163                  Yemen                      1.807460e+08
# 164                 Zambia                      1.250000e+06
# 165               Zimbabwe                      2.240000e+06
#
# [166 rows x 2 columns]

# %%
FMFPDFgrouped.sort_values('Obligations (Historical Dollars)', ascending=False)
# Out:
#                       Country  Obligations (Historical Dollars)
# 75                     Israel                      9.985807e+10
# 48                      Egypt                      4.828408e+10
# 153                    Turkey                      8.968293e+09
# 79                     Jordan                      7.575280e+09
# 62                     Greece                      7.166607e+09
# ..                        ...                               ...
# 53                   Eswatini                      6.389272e+05
# 88                    Lesotho                      5.700562e+05
# 29   Central African Republic                      3.700000e+05
# 36        Congo (Brazzaville)                      3.530000e+05
# 50          Equatorial Guinea                      3.190000e+05
#
# [166 rows x 2 columns]

# %%
MDFgrouped=MDF.groupby('Country')['Obligations (Constant Dollars)'].sum().reset_index()
MDFgrouped.sort_values('Obligations (Constant Dollars)', ascending=False)
# Out:
#                             Country  Obligations (Constant Dollars)
# 89                           Israel                    1.720461e+11
# 0                       Afghanistan                    9.144610e+10
# 195                         Vietnam                    8.540254e+10
# 58                            Egypt                    7.523967e+10
# 185                          Turkey                    4.632681e+10
# ..                              ...                             ...
# 198  Western Europe (not specified)                    1.103259e+05
# 49                           Cyprus                    9.034160e+04
# 174                          Sweden                    5.640337e+04
# 88                          Ireland                    5.521934e+04
# 97                     Korea, North                    8.169007e+03
#
# [203 rows x 2 columns]

# %%
import pandas as pd
USAIDF=pd.read_excel("/Users/lucaslarsen/Documents/CCNY Python Portfolio/foundations-of-data-science/assignments/greenbookUS.xlsx")
GWBDF=USAIDF[USAIDF['Country']=='West Bank/Gaza']
plt.scatter(GWBDF['Fiscal Year'], GWBDF['Obligations (Historical Dollars)'], color='blue')
plt.title('US Aid to Gaza/West Bank')
plt.xlabel('Fiscal Year')
plt.ylabel('Obligations (Historical Dollars)')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()
